# %% [markdown]
# ## Introduction
#
# In this example, we'll build a sequence-to-sequence Transformer model, which
# we'll train on an English-to-Hinglish machine translation task.
#
# Methodology
#
# - Vectorize text using the Keras `TextVectorization` layer.
# - Implement a `TransformerEncoder` layer, a `TransformerDecoder` layer,
# and a `PositionalEmbedding` layer.
# - Prepare data for training a sequence-to-sequence model.
# - Use the trained model to generate translations of never-seen-before
# input sentences (sequence-to-sequence inference).

# %% [markdown]
# ## Setup

# %%
#!pip install datasets

# %%
import pathlib
import random
import string
import re
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import TextVectorization
from datasets import load_dataset
import pickle

# %% [markdown]
# ## Get data
# The data is from hugging face. This dataset features casual tone hinglish translations for english texts. sampled fom various sources (including the Hinglish TOP Dataset)

# %%
dataset_name = "findnitai/english-to-hinglish"
dataset = load_dataset(dataset_name, split="train")

# %%
dataset_dict = dataset.to_dict()

# %%
english = [item['en'] for item in dataset_dict['translation']]
hinglish = [item['hi_ng'] for item in dataset_dict['translation']]

# %% [markdown]
# ## Parsing the data
#
# Each line contains an English sentence and its corresponding Hinglish sentence.
# The English sentence is the *source sequence* and hinglish one is the *target sequence*.
# We prepend the token `"[start]"` and we append the token `"[end]"` to the Spanish sentence.

# %%
def clean_data(text):
  result=[]
  # regex for removing weird chars
  re_print = re.compile('[^%s]' % re.escape(string.printable))
  # regex for removing punctuation
  regex_punct = re.compile('[%s]' % re.escape(string.punctuation))
  for line in text:
    # split on whitespace so we can remove weird chars and punctuation
    line = line.split()
    # convert to lower case
    line = [word.lower() for word in line]
    # remove punctuation
    line = [regex_punct.sub('', word) for word in line]
    # remove weird chars
    line = [re_print.sub('', w) for w in line]
    #remove numbers
    line = [word for word in line if word.isalpha()]
    result.append(' '.join(line))
  return result

# %%
clean_eng = clean_data(english)
clean_hing = clean_data(hinglish)

# %%
#padding clean_hing with [start] and [end] tokens and creating paired
pairs = []
for i in range(len(clean_eng)):
    hing_pad = "[start] "+clean_hing[i]+" [end]"
    pairs.append((clean_eng[i], hing_pad))

# %% [markdown]
# Here's what our sentence pairs look like:

# %%
for _ in range(5):
    print(random.choice(pairs))
# Out:
# ('should i expect any detours on my route to the concert tomorrow', '[start] kya kal concert ke raste me koi detours expect karna chahiye [end]')
# ('find all show tune hits', '[start] saarey show tune hits dhundo [end]')
# ('set alarm for minutes from now', '[start] abhi se minutes ke liye alarm set kare [end]')
# ('set my alarm fifteen minutes prior to next appointment', '[start] agle appointment se fifteen minutes pehle mera alarm set karen [end]')
# ('is there traffic congestion on the freeway', '[start] kya freeway par traffic congestion hai [end]')

# %% [markdown]
# Now, let's split the sentence pairs into a training set, a validation set,
# and a test set.

# %%
random.shuffle(pairs)
num_val_samples = int(0.15 * len(pairs))
num_train_samples = len(pairs) - 2 * num_val_samples
train_pairs = pairs[:num_train_samples]
val_pairs = pairs[num_train_samples : num_train_samples + num_val_samples]
test_pairs = pairs[num_train_samples + num_val_samples :]

print(f"{len(pairs)} total pairs")
print(f"{len(train_pairs)} training pairs")
print(f"{len(val_pairs)} validation pairs")
print(f"{len(test_pairs)} test pairs")
# Out:
# 189102 total pairs
# 132372 training pairs
# 28365 validation pairs
# 28365 test pairs

# %% [markdown]
# ## Vectorizing the text data
#
# We'll use the `TextVectorization` layer to vectorize the text
# data, that is to say, to turn the original strings into integer sequences
# where each integer represents the index of a word in a vocabulary.

# %%
strip_chars = string.punctuation
strip_chars = strip_chars.replace("[", "")
strip_chars = strip_chars.replace("]", "")

vocab_size = 15000
sequence_length = 20
batch_size = 64

eng_vectorization = TextVectorization(
    max_tokens=vocab_size,
    output_mode="int",
    output_sequence_length=sequence_length,
)
hing_vectorization = TextVectorization(
    max_tokens=vocab_size,
    output_mode="int",
    output_sequence_length=sequence_length + 1,
)
train_eng_texts = [pair[0] for pair in train_pairs]
train_hing_texts = [pair[1] for pair in train_pairs]
eng_vectorization.adapt(train_eng_texts)
hing_vectorization.adapt(train_hing_texts)
# Out:
# 2023-11-07 19:18:31.531025: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz

# %% [markdown]
# Save the adapted vectorization layers to load for inference

# %%
pickle.dump({'config': eng_vectorization.get_config(),
             'weights': eng_vectorization.get_weights()}
            , open("./assets/vectors/eng_vectorization.pkl", "wb"))

pickle.dump({'config': hing_vectorization.get_config(),
             'weights': hing_vectorization.get_weights()}
            , open("./assets/vectors/hing_vectorization.pkl", "wb"))

# %% [markdown]
# Next, we'll format our datasets.
#
# At each training step, the model will seek to predict target words N+1 (and beyond)
# using the source sentence and the target words 0 to N.
#
# As such, the training dataset will yield a tuple `(inputs, targets)`, where:
#
# - `inputs` is a dictionary with the keys `encoder_inputs` and `decoder_inputs`.
# `encoder_inputs` is the vectorized source sentence and `decoder_inputs` is the target sentence "so far",
# that is to say, the words 0 to N used to predict word N+1 (and beyond) in the target sentence.
# - `target` is the target sentence offset by one step:
# it provides the next words in the target sentence -- what the model will try to predict.

# %%
def format_dataset(eng, hing):
    eng = eng_vectorization(eng)
    hing = hing_vectorization(hing)
    return (
        {
            "encoder_inputs": eng,
            "decoder_inputs": hing[:, :-1],
        },
        hing[:, 1:],
    )


def make_dataset(pairs):
    eng_texts, hing_texts = zip(*pairs)
    eng_texts = list(eng_texts)
    hing_texts = list(hing_texts)
    dataset = tf.data.Dataset.from_tensor_slices((eng_texts, hing_texts))
    dataset = dataset.batch(batch_size)
    dataset = dataset.map(format_dataset)
    return dataset.shuffle(2048).prefetch(16).cache()


train_ds = make_dataset(train_pairs)
val_ds = make_dataset(val_pairs)

# %% [markdown]
# Let's take a quick look at the sequence shapes
# (we have batches of 64 pairs, and all sequences are 20 steps long):

# %%
for inputs, targets in train_ds.take(1):
    print(f'inputs["encoder_inputs"].shape: {inputs["encoder_inputs"].shape}')
    print(f'inputs["decoder_inputs"].shape: {inputs["decoder_inputs"].shape}')
    print(f"targets.shape: {targets.shape}")
# Out:
# inputs["encoder_inputs"].shape: (64, 20)
# inputs["decoder_inputs"].shape: (64, 20)
# targets.shape: (64, 20)
# 2023-11-07 19:18:43.070598: W tensorflow/core/kernels/data/cache_dataset_ops.cc:856] The calling iterator did not fully read the dataset being cached. In order to avoid unexpected truncation of the dataset, the partially cached contents of the dataset  will be discarded. This can happen if you have an input pipeline similar to `dataset.cache().take(k).repeat()`. You should use `dataset.take(k).cache().repeat()` instead.

# %% [markdown]
# ## Building the model
#
# Our sequence-to-sequence Transformer consists of a `TransformerEncoder`
# and a `TransformerDecoder` chained together. To make the model aware of word order,
# we also use a `PositionalEmbedding` layer.
#
# The source sequence will be pass to the `TransformerEncoder`,
# which will produce a new representation of it.
# This new representation will then be passed
# to the `TransformerDecoder`, together with the target sequence so far (target words 0 to N).
# The `TransformerDecoder` will then seek to predict the next words in the target sequence (N+1 and beyond).
#
# A key detail that makes this possible is causal masking
# (`use_causal_mask=True` in the first attention layer of the `TransformerDecoder`).
# The `TransformerDecoder` sees the entire sequences at once, and thus we must make
# sure that it only uses information from target tokens 0 to N when predicting token N+1
# (otherwise, it could use information from the future, which would
# result in a model that cannot be used at inference time).

# %%
class TransformerEncoder(layers.Layer):
    def __init__(self, embed_dim, dense_dim, num_heads, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = embed_dim
        self.dense_dim = dense_dim
        self.num_heads = num_heads
        self.attention = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim
        )
        self.dense_proj = keras.Sequential(
            [
                layers.Dense(dense_dim, activation="relu"),
                layers.Dense(embed_dim),
            ]
        )
        self.layernorm_1 = layers.LayerNormalization()
        self.layernorm_2 = layers.LayerNormalization()
        self.supports_masking = True

    def call(self, inputs, mask=None):
        attention_output = self.attention(query=inputs, value=inputs, key=inputs)
        proj_input = self.layernorm_1(inputs + attention_output)
        proj_output = self.dense_proj(proj_input)
        return self.layernorm_2(proj_input + proj_output)

    def get_config(self):
        config = super().get_config()
        config.update(
            {
                "embed_dim": self.embed_dim,
                "dense_dim": self.dense_dim,
                "num_heads": self.num_heads,
            }
        )
        return config


class PositionalEmbedding(layers.Layer):
    def __init__(self, sequence_length, vocab_size, embed_dim, **kwargs):
        super().__init__(**kwargs)
        self.token_embeddings = layers.Embedding(
            input_dim=vocab_size, output_dim=embed_dim
        )
        self.position_embeddings = layers.Embedding(
            input_dim=sequence_length, output_dim=embed_dim
        )
        self.sequence_length = sequence_length
        self.vocab_size = vocab_size
        self.embed_dim = embed_dim

    def call(self, inputs):
        length = tf.shape(inputs)[-1]
        positions = tf.range(start=0, limit=length, delta=1)
        embedded_tokens = self.token_embeddings(inputs)
        embedded_positions = self.position_embeddings(positions)
        return embedded_tokens + embedded_positions

    def compute_mask(self, inputs, mask=None):
        return tf.math.not_equal(inputs, 0)

    def get_config(self):
        config = super().get_config()
        config.update(
            {
                "sequence_length": self.sequence_length,
                "vocab_size": self.vocab_size,
                "embed_dim": self.embed_dim,
            }
        )
        return config


class TransformerDecoder(layers.Layer):
    def __init__(self, embed_dim, latent_dim, num_heads, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = embed_dim
        self.latent_dim = latent_dim
        self.num_heads = num_heads
        self.attention_1 = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim
        )
        self.attention_2 = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim
        )
        self.dense_proj = keras.Sequential(
            [
                layers.Dense(latent_dim, activation="relu"),
                layers.Dense(embed_dim),
            ]
        )
        self.layernorm_1 = layers.LayerNormalization()
        self.layernorm_2 = layers.LayerNormalization()
        self.layernorm_3 = layers.LayerNormalization()
        self.add = layers.Add()  # instead of `+` to preserve mask
        self.supports_masking = True

    def call(self, inputs, encoder_outputs, mask=None):
        attention_output_1 = self.attention_1(
            query=inputs, value=inputs, key=inputs, use_causal_mask=True
        )
        out_1 = self.layernorm_1(self.add([inputs, attention_output_1]))

        attention_output_2 = self.attention_2(
            query=out_1,
            value=encoder_outputs,
            key=encoder_outputs,
        )
        out_2 = self.layernorm_2(self.add([out_1, attention_output_2]))

        proj_output = self.dense_proj(out_2)
        return self.layernorm_3(self.add([out_2, proj_output]))

    def get_config(self):
        config = super().get_config()
        config.update(
            {
                "embed_dim": self.embed_dim,
                "latent_dim": self.latent_dim,
                "num_heads": self.num_heads,
            }
        )
        return config

# %% [markdown]
# Next, we assemble the end-to-end model.

# %%
embed_dim = 256
latent_dim = 2048
num_heads = 8

encoder_inputs = keras.Input(shape=(None,), dtype="int64", name="encoder_inputs")
x = PositionalEmbedding(sequence_length, vocab_size, embed_dim)(encoder_inputs)
encoder_outputs = TransformerEncoder(embed_dim, latent_dim, num_heads)(x)
encoder = keras.Model(encoder_inputs, encoder_outputs)

decoder_inputs = keras.Input(shape=(None,), dtype="int64", name="decoder_inputs")
encoded_seq_inputs = keras.Input(shape=(None, embed_dim), name="decoder_state_inputs")
x = PositionalEmbedding(sequence_length, vocab_size, embed_dim)(decoder_inputs)
x = TransformerDecoder(embed_dim, latent_dim, num_heads)(x, encoded_seq_inputs)
x = layers.Dropout(0.5)(x)
decoder_outputs = layers.Dense(vocab_size, activation="softmax")(x)
decoder = keras.Model([decoder_inputs, encoded_seq_inputs], decoder_outputs)

decoder_outputs = decoder([decoder_inputs, encoder_outputs])
transformer = keras.Model(
    [encoder_inputs, decoder_inputs], decoder_outputs, name="transformer"
)

# %% [markdown]
# ## Training our model
#
# We'll use accuracy as a quick way to monitor training progress on the validation data.
# Note that machine translation typically uses BLEU scores as well as other metrics, rather than accuracy.

# %%
checkpoint = tf.keras.callbacks.ModelCheckpoint(
        'models/{epoch:02d}-{val_loss:.2f}.h5',
        verbose=1,
        save_best_only=True
    )

# %%
epochs = 1  # This should be at least 30 for convergence

transformer.summary()
transformer.compile(
    "rmsprop", loss="sparse_categorical_crossentropy", metrics=["accuracy"]
)
history = transformer.fit(train_ds, epochs=epochs, validation_data=val_ds, callbacks = [checkpoint])
# Out:
# Model: "transformer"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  encoder_inputs (InputLayer)    [(None, None)]       0           []
#
#  positional_embedding (Position  (None, None, 256)   3845120     ['encoder_inputs[0][0]']
#  alEmbedding)
#
#  decoder_inputs (InputLayer)    [(None, None)]       0           []
#
#  transformer_encoder (Transform  (None, None, 256)   3155456     ['positional_embedding[0][0]']
#  erEncoder)
#
#  model_1 (Functional)           (None, None, 15000)  12959640    ['decoder_inputs[0][0]',
#                                                                   'transformer_encoder[0][0]']
#
# ==================================================================================================
# Total params: 19,960,216
# Trainable params: 19,960,216
# Non-trainable params: 0
# __________________________________________________________________________________________________
# 2069/2069 [==============================] - ETA: 0s - loss: 2.9949 - accuracy: 0.5519
# Epoch 1: val_loss improved from inf to 2.18082, saving model to models/01-2.18.h5
# 2069/2069 [==============================] - 712s 342ms/step - loss: 2.9949 - accuracy: 0.5519 - val_loss: 2.1808 - val_accuracy: 0.6522

# %% [markdown]
# ## Decoding test sentences
#
# Finally, let's demonstrate how to translate brand new English sentences.
# We simply feed into the model the vectorized English sentence
# as well as the target token `"[start]"`, then we repeatedly generated the next token, until
# we hit the token `"[end]"`.

# %%
hing_vocab = hing_vectorization.get_vocabulary()
hing_index_lookup = dict(zip(range(len(hing_vocab)), spa_vocab))
max_decoded_sentence_length = 20


def decode_sequence(input_sentence):
    tokenized_input_sentence = eng_vectorization([input_sentence])
    decoded_sentence = "[start]"
    for i in range(max_decoded_sentence_length):
        tokenized_target_sentence = hing_vectorization([decoded_sentence])[:, :-1]
        predictions = transformer([tokenized_input_sentence, tokenized_target_sentence])

        sampled_token_index = np.argmax(predictions[0, i, :])
        sampled_token = hing_index_lookup[sampled_token_index]
        decoded_sentence += " " + sampled_token

        if sampled_token == "[end]":
            break
    return decoded_sentence


test_eng_texts = [pair[0] for pair in test_pairs]
for _ in range(30):
    input_sentence = random.choice(test_eng_texts)
    translated = decode_sequence(input_sentence)
    print("\ninput: ", input_sentence, "\ntranslated: ", translated)
# Out:
# input:  delete the am alarm for the next two days please
# translated:  [start] please agley do din ke liye subah baje ke liye alarm ko delete kare end  kar kar kar kar
#
# input:  reminder to set up programs for the estate sale in march
# translated:  [start] the [UNK] me the food ke liye reminder set kare to the mall end  end end end kar end
#
# input:  ignore video messages
# translated:  [start] video messages ko bajao end  kar kar [UNK] [UNK] [UNK] [UNK] end [UNK] end kar end kar [UNK] [UNK]
#
# input:  set an alarm for tomorrow
# translated:  [start] kal ke liye ek alarm set karen end  kar kar kar kar end kar kar end kar end
#
# input:  important alarm to set saturday evening at pm
# translated:  [start] saturday shaam baje ke liye alarm set kare end  karne karne end end kar end end kar
#
# input:  play alternative music
# translated:  [start] music bajao end  [UNK] [UNK] [UNK] [UNK] [UNK] end [UNK] [UNK] end [UNK] end [UNK] end [UNK] [UNK] [UNK]
#
# input:  show me one way options to auditorium by am via ave
# translated:  [start] mujhe am tak pahunchne ke liye ek [UNK] [UNK] ke liye [UNK] [UNK] [UNK] [UNK] [UNK] [UNK] [UNK] [UNK] [UNK]
#
# input:  how heavy is traffic between portland and salem
# translated:  [start] portland aur portland ke beech me traffic kitna heavy hai end  hai end end hai end end end end
#
# input:  change my eye appointment reminder from monday to next wednesday
# translated:  [start] mere doctor ke appointment reminder ko agle monday se wednesday tak badal do end  karne end hai end end
#
# input:  what is the distance from usa to china
# translated:  [start] the the the the the the the the the the the the the the mall tak ka distance end
#
# input:  change reminder to wednesday
# translated:  [start] reminder ko wednesday me badal do end  [UNK] karne end kar end end kar kar end kar end [UNK]
#
# input:  resume current timer
# translated:  [start] current timer ko resume kare end  [UNK] [UNK] [UNK] [UNK] [UNK] end [UNK] end kar end [UNK] end [UNK]
#
# input:  remind me to check in with susan friday
# translated:  [start] mujhe friday ko meri check karne ke liye yaad dilaye end  karne end end hai end end end ko
#
# input:  cancel my alarm tomorrow
# translated:  [start] kal mera alarm cancel kare end  [UNK] [UNK] [UNK] [UNK] [UNK] [UNK] [UNK] end [UNK] end [UNK] [UNK] [UNK]
#
# input:  events for seniors this week
# translated:  [start] is haftey ke liye events hai end  [UNK] [UNK] [UNK] [UNK] end end kar kar end end [UNK] [UNK]
#
# input:  should we marry
# translated:  [start] kya mujhe chahiye end  [UNK] kar [UNK] [UNK] [UNK] [UNK] [UNK] [UNK] [UNK] end [UNK] end [UNK] [UNK] [UNK]
#
# input:  hmm not sure it was released year so it probably is
# translated:  [start] ye saal hai ki ye bhi bhi bhi nahi hai end  end end kar kar end end kar kar
#
# input:  tell john that he need to do something
# translated:  [start] john ko bolo ki mujhe kuch karna hai end  karne karne hai end end end end end karne end
#
# input:  how long of a delay will there be in washington dc due to traffic at today on my way
# translated:  [start] aaj traffic me meri drive par kitna samay lagega end  karne par hoga karne par end hoga end end
#
# input:  set an alarm for am next monday
# translated:  [start] agley monday subah baje ke liye alarm set kare end  kar end kar kar kar end end kar end
#
# input:  can i get the day forecast for phoenix
# translated:  [start] kya mai phoenix ka forecast mil sakta hoon end  kar kar end kar kar end kar do end end
#
# input:  movie theaters near me
# translated:  [start] mere aas paas ke hai end  [UNK] end end [UNK] [UNK] end end end kar end [UNK] [UNK] [UNK]
#
# input:  delete all my alarms for the past month
# translated:  [start] mahine ke liye mere sabhi alarms delete karo end  kar kar [UNK] end kar kar end kar end [UNK]
#
# input:  can you tell me the weather forecast for france
# translated:  [start] kya aap mujhe sydney ke liye weather forecast bata sakte hai end  hai end end end kar end kar
#
# input:  can you inform e if its going to be sunny today
# translated:  [start] kya aap bata sakte hai ki aaj dhoop hogi end  end end kar end kar end kar end kar
#
# input:  truth is the same to all nations he had said but each nation has its lies which it speaks of as its idealism
# translated:  [start] ye bhi bhi bhi hai ki [UNK] hai kya [UNK] [UNK] [UNK] [UNK] [UNK] [UNK] [UNK] [UNK] [UNK] [UNK] [UNK]
#
# input:  set an alarm for later this afternoon
# translated:  [start] is dopahar ke liye ek alarm set karen end  kar kar kar kar kar kar end do end [UNK]
#
# input:  start the timer and set the alarm for every minutes for the first minutes then every minutes for the next minutes
# translated:  [start] har minutes ke liye timer ko minutes aur minutes ke liye set kiya hua hai end  kare karne minutes
#
# input:  delete all alarms that are set for tuesday
# translated:  [start] tuesday ke liye sabhi alarms delete karo jo set hai end  ho hai end end end kar kar end
#
# input:  give weather at pm
# translated:  [start] pm ko mausam ke baare me bataye end  kar kar kar end kar end kar end kar end [UNK]

# %%
# !pip install pyyaml h5py  # Required to save models in HDF5 format
# Out:
# Requirement already satisfied: pyyaml in /Users/haseeb/miniconda3/envs/English2Hinglish_tf/lib/python3.10/site-packages (6.0)
# Requirement already satisfied: h5py in /Users/haseeb/miniconda3/envs/English2Hinglish_tf/lib/python3.10/site-packages (3.9.0)
# Requirement already satisfied: numpy>=1.17.3 in /Users/haseeb/miniconda3/envs/English2Hinglish_tf/lib/python3.10/site-packages (from h5py) (1.23.5)

# %%
# save the model weights
transformer.save_weights('./models/model_wts/test')

# %%
# save the entire model 
transformer.save('./models/test.h5')
